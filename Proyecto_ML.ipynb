# %% [markdown]
# <center><font face="Arial" size=7 color=black> <font><b> 🧠⚙️ Machine Learning ⚙️🧠 </b></center>

# %% [markdown]
# <div style="text-align: center;">
#                       <h1>Introducción</h1>
# </div>
#
# <div style="font-family: Arial, sans-serif; line-height: 1.6; padding: 20px; border-radius: 10px; background-color: #f4f4f4;">
#     <p>
#         En el sector bancario, los depósitos a plazo fijo se destacan como un producto financiero esencial que ofrece a los clientes la oportunidad de ahorrar e invertir su dinero, obteniendo una rentabilidad en forma de intereses. Para las entidades bancarias, estos depósitos representan una fuente crucial de ingresos, ya que el dinero depositado se convierte en capital activo que puede ser utilizado en diversas operaciones financieras.
#     </p>
#     <p>
#         Para promover la contratación de estos productos, las campañas telefónicas han demostrado ser una estrategia eficiente. A pesar del desafío de gestionar una amplia cartera de clientes, estas campañas permiten identificar oportunidades y acercar a los usuarios hacia este tipo de soluciones financieras.
#     </p>
#     <p>
#         En este contexto, una entidad bancaria anónima ha implementado distintas estrategias con el objetivo de identificar a los clientes con mayor probabilidad de contratar un depósito a plazo fijo, optimizando así sus esfuerzos y resultados. Los objetivos de este análisis son:
#     </p>
#     <ul>
#         1.   Realizar un estudio exploratorio (EDA) sobre las características de los distintos tipos de clientes.
#         </p>
#         2.   Predecir qué clientes tienen más probabilidades de contratar el producto.
#         </p>
#         3. Considerar cómo llevar la solución a producción, evaluando las implicaciones y consideraciones relevantes para su implementación (sin entrar en detalles técnicos específicos).
#         </p>
#         4. Explicar los resultados obtenidos.
#     </ul>
#
# </div>

# %% [markdown]
# ##**0. Lectura de archivos e importar librerías**

# %% [markdown]
# ### **0.1 Importar las librerías 📚**

# %%
import os

import pandas as pd
import math
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

import math
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### **0.2 Montar Drive ⚙️**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Establecer directorio de trabajo (donde están los archivos)
os.chdir('/content/drive/MyDrive/Colab Notebooks')

# %% [markdown]
#  ### **0.3 Cargar y leer archivo de entrenamiento 📂**

# %% [markdown]
# ##**1. Análisis, limpieza y transformaciones**

# %% [markdown]
#  ## **2. Entrenamiento ⚙️⚙️**

# %% [markdown]
# ###**2.1 Preparación de los datos y selección del modelo 🌟**

# %% [markdown]
# ###**2.2 Entrenamiento de los modelos**

# %% [markdown]
#  ## **3. Evaluación de los modelos 📊**

# %% [markdown]
# ### **3.1 Evaluación del conjunto *train***

# %% [markdown]
# ### **3.2 Evaluación del conjunto *test***

# %% [markdown]
# ## **4. Mejora del modelo 🏆**

# %% [markdown]
# ### **4.1 Re-entrenamiento del modelo mejorado ⏳**

# %% [markdown]
# ### **4.2 Evaluación del modelo mejorado**

# %% [markdown]
# ## **5.  Predicciones y rendimiento en nuevos datos: fichero *test* 🔎**

# %% [markdown]
#  ### **5.0 Cargar archivo de test 📂**

# %% [markdown]
# ### **5.1 Pre-procesamiento y transformación de los datos 📋**

# %% [markdown]
# ### **5.2 Predicción y evaluación 📊**

# %% [markdown]
# ##**6. Llevar el modelo a Producción**
